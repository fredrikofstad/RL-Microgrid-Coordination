# %%
#Extract data from load files

import os
import glob
import pandas as pd
import numpy as np
import pandas as pd
from IPython.display import display 
import nltk
from nltk import sent_tokenize,word_tokenize
import itertools
from nltk.tokenize.treebank import TreebankWordDetokenizer

directory_path="C:/Users/rasyd/Documents/in5460/oblig1"
entries = os.listdir(directory_path)

folders = [entry for entry in entries if os.path.isdir(os.path.join(directory_path, entry))]

folder_list=[os.path.join(directory_path, folder) for folder in folders]
folder_list=[folder_list[6],folder_list[7],folder_list[8]]

combined_data2 = pd.DataFrame()

for folder in folder_list:
    folder_path = folder 
    # Initialize an empty DataFrame to store the combined data'C:/Users/rasyd/Documents/in5460/oblig1/USA_AK_Anchorage.Intl.AP.702730_TMY3'
    combined_data = pd.DataFrame()
    
    # Use glob to get a list of all files in the folder with a specific extension
    file_extension = '*.csv'  # Change this to the desired file extension, such as '*.csv'
    files = glob.glob(os.path.join(folder_path, file_extension))
    
    # Loop through the list of files and add their columns to the combined_data DataFrame
    for file_path in files:
    # Read the current file into a DataFrame
        current_data = pd.read_csv(file_path)
        
        tokenize_col=current_data.columns
        
        
        
        tokenized_sentences_list = [sent_tokenize(text) for text in tokenize_col]
        tokenized_sentences_list = [word_tokenize(text) for text in tokenize_col]
        
        
        occurrences_electricity = np.array([(i, j) for i, sublist in enumerate(tokenized_sentences_list) for j, word in enumerate(sublist) if word == 'Electricity'])[:,0]
        
        
        Electricity_consumption_wind_solar=current_data[tokenize_col[occurrences_electricity]].sum(axis=1)
        
        current_data=Electricity_consumption_wind_solar
        
        
        # Add the columns of the current file to the combined_data DataFrame
        combined_data = pd.concat([combined_data, current_data], axis=1)
        
        # Now, combined_data contains the columns from all the imported files
        #print(combined_data.sum(axis=1))
        Series_type=combined_data.sum(axis=1)
        house_hold_data=Series_type.to_frame("Household_load")
    combined_data2= pd.concat([combined_data2,house_hold_data ], axis=1)
Series_type=combined_data2.sum(axis=1)
total_energy=Series_type.to_frame("Household_load")
total_energy=np.array(total_energy).ravel()

total_energy
# Out:
# array([ 9717.11173726,  9150.01132959,  9246.76820263, ...,
#        11952.92251165, 11044.33630981, 10465.73332243])

# %%
import numpy as np
import gym
from gym import spaces
from gym.spaces import Box, Dict, Discrete, MultiBinary, MultiDiscrete
import numpy as np
from stable_baselines3 import PPO,A2C
import numpy as np
import pandas as pd
from IPython.display import display 
import nltk
from nltk import sent_tokenize,word_tokenize
import itertools
from nltk.tokenize.treebank import TreebankWordDetokenizer

# the cut -in windspeed (km/h =1/3.6 m/s), v^ci#
cutin_windspeed = 3*3.6
# the cut -off windspeed (km/h =1/3.6 m/s), v^co#
cutoff_windspeed = 11*3.6
# the rated windspeed (km/h =1/3.6 m/s), v^r#
rated_windspeed = 7*3.6
# the charging - discharging efficiency , eta#
charging_discharging_efficiency = 0.95
# the rate for discharging the battery ( MegaWatt ), b#
rate_battery_discharge = 2/1000
# the unit operational and maintanance cost for generating power
# from solar PV (10^4 $/ MegaWattHour =10 $/ kWHour ), r_omc ^s#
unit_operational_cost_solar = 0.00015/10
# the unit operational and maintanance cost for generating power
# from wind turbine (10^4 $/ MegaWattHour =10 $/ kWHour ), r_omc ^w#
unit_operational_cost_wind = 0.00085/10
# the unit opeartional and maintanance cost for generating power
# from generator (10^4 $/ MegaWattHour =10 $/ kWHour ), r_omc ^g#
unit_operational_cost_generator = 0.02/10
# the unit operational and maintanance cost for battery storage system
# per unit charging / discharging cycle (10^4 $/ MegaWattHour =10 $/ kWHour ),
# r_omc ^b#
unit_operational_cost_battery = 0.0095/10
# the capacity of battery storage system ( MegaWatt Hour =1000 kWHour ), e#
capacity_battery_storage = 300/1000
# the maximum state of charge of battery system #
SOC_max = 0.95* capacity_battery_storage
# the minimum state of charge of battery system #
SOC_min = 0.05* capacity_battery_storage
# the area of the solar PV system (km ^2=1000*1000 m^2) , a#
area_solarPV = 1400000000/(1000*1000)
# the efficiency of the solar PV system , delta #
efficiency_solarPV = 0.2
# calculate the rated power of the wind turbine ,
# density of air (10^6 kg/km ^3=1 kg/m^3) , rho#
density_of_air = 1.225
# calculate the rated power of the wind turbine ,
# radius of the wind turbine blade (km =1000 m), r#
radius_wind_turbine_blade = 25/1000
# calculate the rated power of the wind turbine ,
# average wind speed (km/h =1/3.6 m/s), v_avg ( from the windspeed table )#
average_wind_speed = 3.952*3.6
# calculate the rated power of the wind turbine , power coefficient , theta #
power_coefficient = 0.593
# calculate the rated power of the wind turbine ,
# gearbox transmission efficiency , eta_t #
gearbox_transmission_efficiency = 0.95
# calculate the rated power of the wind turbine ,
# electrical generator efficiency , eta_g #
electrical_generator_efficiency = 0.95
# the rated power of the wind turbine , RP_w ( MegaWatt =10^6 W),
# with the radius_wind_turbine_blade measured in km =10^3m,
# average wind speed measured in km/ hour =3.6 m/s,
# RP_w will be calculated as RP_w_numerical
# then RP_w in MegaWatt =(1 kg/m^3) *(10^3 m) *(10^3 m)
# *(3.6 m/s) *(3.6 m/s) *(3.6 m/s)* RP_w_numerical
# =3.6^3*10^6 RP_w_numerical W =3.6^3 RP_w_numerical MegaWatt #
rated_power_wind_turbine_original =\
    (0.5 * density_of_air * np.pi
     * radius_wind_turbine_blade
     * radius_wind_turbine_blade
     * average_wind_speed
     * average_wind_speed
     * average_wind_speed
     * power_coefficient
     * gearbox_transmission_efficiency
     * electrical_generator_efficiency)
rated_power_wind_turbine = rated_power_wind_turbine_original / (3.6*3.6*3.6)
# the number of wind turbine in the onsite generation system , N_w#
number_windturbine = 2000
# the number of generators , n_g#

number_generators=40
# the rated output power of the generator ( MegaWatt =1000 kW), G_p#
rated_output_power_generator = 600/1000

unit_reward_soldbackenergy=3





# read the solar irradiance and wind speed data from file #
# read the rate of consumption charge date from file #
file_SolarIrradiance = "SolarIrradiance.csv"
file_WindSpeed = "WindSpeed.csv"
file_rateConsumptionCharge = "rate_consumption_charge.csv"
# read the solar irradiace
data_solar = pd.read_csv(file_SolarIrradiance)

# solar irradiance measured by MegaWatt /km ^2
solarirradiance = np.array( data_solar.iloc[: ,3].dropna())
# read the windspeed
data_wind = pd.read_csv( file_WindSpeed )
windspeed = 3.6* np.array( data_wind.iloc[: ,3].dropna())# windspeed measured by km/h =1/3.6 m/s

# read the rate of consumption charge
data_rate_consumption_charge =pd.read_csv( file_rateConsumptionCharge ).dropna()
#rate_consumption_charge = np.array( data_rate_consumption_charge.iloc[: ,4])/10
# rate of consumption charge measured by 10^4 $/ MegaWatt =10 $/kWh





P_g_t=np.array( data_rate_consumption_charge.iloc[: ,4])/10 #cost of using windmills,and PV and genrerator for microgrid





def generate_binary_combinations(num_vars):
    # Generate all binary combinations for num_vars as a list of lists
    binary_combinations = np.unpackbits(np.arange(2**num_vars, dtype=np.uint8)[:, np.newaxis], axis=1)
    binary_combinations = binary_combinations[:, -num_vars:]
    binary_combinations_list = binary_combinations.tolist()
    return binary_combinations_list




class Microgrid:
    def __init__(self,
                 workingstatus=np.array([0, 0, 0]),
                 SOC=0,
                 actions_adjustingstatus=np.array([0, 0, 0]),
                 actions_solar=np.array([0, 0, 0]),
                 actions_wind=np.array([0, 0, 0]),
                 actions_generator=np.array([0, 0, 0]),
                 actions_purchased=np.array([0, 0]),
                 actions_discharged=0,
                 solarirradiance=solarirradiance,
                 windspeed=windspeed):
        self.workingstatus = workingstatus
        self.SOC = SOC
        self.actions_adjustingstatus = actions_adjustingstatus
        self.actions_solar = actions_solar
        self.actions_wind = actions_wind
        self.actions_generator = actions_generator
        self.actions_purchased = actions_purchased
        self.actions_discharged = actions_discharged
        self.solarirradiance = solarirradiance
        self.windspeed = windspeed
        self.count=0
        
    def transition(self):
       
        workingstatus = self.workingstatus
        SOC = self.SOC
        if self.actions_adjustingstatus[0] == 1:
            workingstatus[0] = 1
        else:
            workingstatus[0] = 0
        
        if self.actions_adjustingstatus[1] == 1 or (self.solarirradiance[self.count] * efficiency_solarPV * efficiency_solarPV / 1000 > 0):
            workingstatus[1] = 1
        
        if self.actions_adjustingstatus[1] == 1 and cutoff_windspeed >= self.windspeed[self.count] >= cutin_windspeed:
            workingstatus[1] = 1
        
        if self.actions_adjustingstatus[2] == 1:
            workingstatus[2] = 1
        else:
            workingstatus[2] = 0
        
        SOC = (self.SOC + (self.actions_solar[1] + self.actions_wind[1] + self.actions_generator[1]
                           + self.actions_purchased[1]) * charging_discharging_efficiency
               - self.actions_discharged / charging_discharging_efficiency)
        #print(SOC)
        SOC = max(min(SOC, SOC_max), SOC_min)
        
        return workingstatus, SOC

    def EnergyConsumption(self):

     
        return -(self.actions_solar[0] + self.actions_wind[0] + self.actions_generator[0] + self.actions_discharged)

    def energy_generated_solar(self):
        #print(self.solarirradiance[self.count])
        if self.workingstatus[0] == 1:
            energy_generated_solar = self.solarirradiance[self.count] * area_solarPV * efficiency_solarPV/1000 
        else:
            energy_generated_solar = 0
        return energy_generated_solar

    def energy_generated_wind(self):
        Delta_t=1
        if self.workingstatus[1] == 1 and rated_windspeed > self.windspeed[self.count] >= cutin_windspeed:
            energy_generated_wind = (number_windturbine
                                     * rated_power_wind_turbine
                                     * (self.windspeed[self.count] - cutin_windspeed) / (rated_windspeed - cutin_windspeed))
        else:
            #if self.workingstatus[1] == 1 and cutoff_windspeed > self.windspeed[self.count] >= rated_windspeed:
                #energy_generated_wind = number_windturbine * rated_power_wind_turbine * Delta_t
            #else:
            energy_generated_wind = 0
        return energy_generated_wind

    def energy_generated_generator(self):
        Delta_t=1
        if self.workingstatus[2] == 1:
            energy_generated_generator = number_generators * rated_output_power_generator * Delta_t
        else:
            energy_generated_generator = 0
        return energy_generated_generator

    def OperationalCost(self):
        Delta_t=1
        energy_generated_solar = self.energy_generated_solar()
        energy_generated_wind = self.energy_generated_wind()
        energy_generated_generator = self.energy_generated_generator()
        
        operational_cost = (energy_generated_solar * unit_operational_cost_solar
                            + energy_generated_wind * unit_operational_cost_wind
                            + energy_generated_generator * unit_operational_cost_generator)
        
        operational_cost += ((self.actions_discharged + self.actions_solar[1] + self.actions_wind[1] +
                              self.actions_generator[1]) * Delta_t * unit_operational_cost_battery /
                             (2 * capacity_battery_storage * (SOC_max - SOC_min)))
        
        return operational_cost

    def SoldBackReward(self):
      
        return ((self.actions_solar[2] + self.actions_wind[2] + self.actions_generator[2]) *
                unit_reward_soldbackenergy)

    
        
        




class CustomEnv(gym.Env):
    def __init__(self, binary_combinations_1, binary_combinations_2, binary_combinations_3,P_g_t,windspeed,solarirradiance,total_energy,number_generators):
        super(CustomEnv, self).__init__()
       
        #self.binary_combinations_1 = binary_combinations_1
        #self.binary_combinations_2 = binary_combinations_2
        #self.binary_combinations_3 = binary_combinations_3
        self.microgrid_instance = None
        self.count=0
        self.mutiply=0
        self.observation_space = spaces.Box(low=np.array([0, 0, 0, 0,0,0,0]), high=np.array([1, 1, 1, 1000,1000,1000,1000]), dtype=np.float32)
        self.action_space = MultiDiscrete([8, 8, 8, 8, 4, 2])
        
    def step(self, action):
        
       #if you want another episode lenght smaller then data size activate multiply in if done condition further down
        self.microgrid_instance.count=self.microgrid_instance.count+self.mutiply*(self.count-1)+1
        
        #print(self.microgrid_instance.count)
        adjusting_status = binary_combinations_3[action[0]]
        solar_actions = binary_combinations_3[action[1]]
        wind_actions = binary_combinations_3[action[2]]
        generator_actions = binary_combinations_3[action[3]]
        purchased_actions = binary_combinations_2[action[4]]
        purchased_discharged = binary_combinations_1[action[5]]

        """
        adjusting_status = action[0:3]
        solar_actions = action[3:6]
        wind_actions = action[6:9]
        generator_actions = action[9:12]
        purchased_actions = action[12:14]
        purchased_discharged = action[14]
        """
        self.microgrid_instance.actions_adjustingstatus = np.array(adjusting_status)
        self.microgrid_instance.actions_solar = np.array(solar_actions)
        self.microgrid_instance.actions_wind = np.array(wind_actions)
        self.microgrid_instance.actions_generator = np.array(generator_actions)
        self.microgrid_instance.actions_purchased = np.array(purchased_actions)
        self.microgrid_instance.actions_discharged = purchased_discharged[0]*rate_battery_discharge  
     
        
        """
        print("Actions Solar Shape:", self.microgrid_instance.actions_solar.shape)
        print("Actions Wind Shape:", self.microgrid_instance.actions_wind.shape)
        print("Actions Generator Shape:", self.microgrid_instance.actions_generator.shape)
        print("Actions Purchased Shape:", self.microgrid_instance.actions_purchased.shape)
        """
        #print(self.microgrid_instance.transition())
        state_working_space,state_Soc = self.microgrid_instance.transition()
        state=np.concatenate((state_working_space, [state_Soc,total_energy[self.microgrid_instance.count],
                                  windspeed[self.microgrid_instance.count],solarirradiance[self.microgrid_instance.count]])).astype(int)
        #self.microgrid_instance.SoldBackReward()=microgrid_instance.SoldBackReward()
        S_t = self.microgrid_instance.SoldBackReward()
        O_t = self.microgrid_instance.OperationalCost()
       #converting to KW from MW
        Total_E_t_micro = 1000*(self.microgrid_instance.energy_generated_solar()+self.microgrid_instance.energy_generated_wind()+self.microgrid_instance.energy_generated_generator())
        #print(self.microgrid_instance.energy_generated_generator())
        #print(self.Total_E_t_micro)

        #Calculate the energy needed for the load after generation and buy thhe rest, self.microgrid_instance.EnergyConsumption() is negative
        Rest_after_consumption = (total_energy[self.microgrid_instance.count]+Total_E_t_micro*self.microgrid_instance.EnergyConsumption())
        if Rest_after_consumption>0: 
           self.microgrid_instance.actions_purchased[0]=1 
           E_t=self.microgrid_instance.actions_purchased[0]*Rest_after_consumption*P_g_t[self.microgrid_instance.count]
         
        else:
             
             E_t=0
             
        #*self.microgrid_instance.EnergyConsumption()
      
        
        reward =(E_t+O_t - S_t)
        
        
        #print(P_g_t[self.microgrid_instance.count])
        
        done=False
        if self.microgrid_instance.count==8639:
           done = True
           #self.count+=163
           #self.mutiply+1
        #print( self.reward )

        
        info={"Solar_power_generation":self.microgrid_instance.energy_generated_solar(),
              "Wind_power_generation":self.microgrid_instance.energy_generated_wind(),
             "energy_generated_generator":self.microgrid_instance.energy_generated_generator(),
             "reward":reward,
              "S_t":S_t,
              "O_t":O_t,
              "E_t":E_t,
              "state_Soc":state_Soc
             }
        return state, reward, done,info 
        
    def reset(self):
        self.microgrid_instance = Microgrid()  # Create a new Microgrid instance for each episode
        state_working_space,state_Soc = self.microgrid_instance.transition()
        
        state=np.concatenate((state_working_space, [state_Soc,total_energy[self.microgrid_instance.count],
                                  windspeed[self.microgrid_instance.count],solarirradiance[self.microgrid_instance.count]])).astype(int)
        #self.microgrid_instance.count=self.microgrid_instance.count+10*self.count
        #self.microgrid_instance.count=self.count 
        #print(self.state)
        return state

    def render(self):
        pass



num_binary_vars = 3  # Change this to the number of binary variables you have
binary_combinations_3 = generate_binary_combinations(num_binary_vars)

num_binary_vars = 2  # Change this to the number of binary variables you have
binary_combinations_2 = generate_binary_combinations(num_binary_vars)

num_binary_vars = 1  # Change this to the number of binary variables you have
binary_combinations_1 = generate_binary_combinations(num_binary_vars)


env = CustomEnv( binary_combinations_1, binary_combinations_2, binary_combinations_3,np.array(P_g_t), np.array(windspeed),np.array(solarirradiance),np.array(total_energy),number_generators)


model = PPO("MlpPolicy", env, verbose=1,ent_coef=0.01,policy_kwargs={"net_arch": [64, 64]},learning_rate=0.01)

model.learn(total_timesteps=int(1e5))

learned_policy = model.policy

obs = env.reset()  # Reset the environment to get the initial observation/state
done = False  # Set the done flag to False initially
# Out:
# C:\Users\rasyd\anaconda3\envs\micro\lib\site-packages\gym\spaces\box.py:127: UserWarning: WARN: Box bound precision lowered by casting to float32
#   logger.warn(f"Box bound precision lowered by casting to {self.dtype}")
# Using cpu device
# C:\Users\rasyd\anaconda3\envs\micro\lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# -----------------------------
# | time/              |      |
# |    fps             | 530  |
# |    iterations      | 1    |
# |    time_elapsed    | 3    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 428         |
# |    iterations           | 2           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.021080509 |
# |    clip_fraction        | 0.426       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.4       |
# |    explained_variance   | 6.62e-05    |
# |    learning_rate        | 0.01        |
# |    loss                 | 4.27e+04    |
# |    n_updates            | 10          |
# |    policy_gradient_loss | 0.013       |
# |    value_loss           | 1.52e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 404         |
# |    iterations           | 3           |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.010613293 |
# |    clip_fraction        | 0.173       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.4       |
# |    explained_variance   | -2.38e-07   |
# |    learning_rate        | 0.01        |
# |    loss                 | 9.14e+05    |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00964    |
# |    value_loss           | 1.64e+06    |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 391        |
# |    iterations           | 4          |
# |    time_elapsed         | 20         |
# |    total_timesteps      | 8192       |
# | train/                  |            |
# |    approx_kl            | 0.01091557 |
# |    clip_fraction        | 0.167      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -10.3      |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.01       |
# |    loss                 | 1.98e+06   |
# |    n_updates            | 30         |
# |    policy_gradient_loss | -0.0143    |
# |    value_loss           | 3.64e+06   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.64e+03    |
# |    ep_rew_mean          | 5.43e+05    |
# | time/                   |             |
# |    fps                  | 387         |
# |    iterations           | 5           |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.012667294 |
# |    clip_fraction        | 0.217       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.3       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.01        |
# |    loss                 | 4.57e+05    |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00545    |
# |    value_loss           | 9.13e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.64e+03    |
# |    ep_rew_mean          | 5.43e+05    |
# | time/                   |             |
# |    fps                  | 377         |
# |    iterations           | 6           |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.019838527 |
# |    clip_fraction        | 0.315       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.2       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.01        |
# |    loss                 | 7.14e+04    |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0113     |
# |    value_loss           | 1.8e+05     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.64e+03    |
# |    ep_rew_mean          | 5.43e+05    |
# | time/                   |             |
# |    fps                  | 369         |
# |    iterations           | 7           |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.010756411 |
# |    clip_fraction        | 0.152       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.2       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.01        |
# |    loss                 | 8.71e+05    |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00986    |
# |    value_loss           | 1.89e+06    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.64e+03    |
# |    ep_rew_mean          | 5.43e+05    |
# | time/                   |             |
# |    fps                  | 365         |
# |    iterations           | 8           |
# |    time_elapsed         | 44          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.010605609 |
# |    clip_fraction        | 0.121       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.2       |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.01        |
# |    loss                 | 2.94e+06    |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0121     |
# |    value_loss           | 6.41e+06    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.64e+03    |
# |    ep_rew_mean          | 6.53e+05    |
# | time/                   |             |
# |    fps                  | 365         |
# |    iterations           | 9           |
# |    time_elapsed         | 50          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.011548224 |
# |    clip_fraction        | 0.156       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.1       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.01        |
# |    loss                 | 1.3e+06     |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0128     |
# |    value_loss           | 2.68e+06    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.64e+03    |
# |    ep_rew_mean          | 6.53e+05    |
# | time/                   |             |
# |    fps                  | 366         |
# |    iterations           | 10          |
# |    time_elapsed         | 55          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.018217236 |
# |    clip_fraction        | 0.252       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10         |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.01        |
# |    loss                 | 8.55e+04    |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00674    |
# |    value_loss           | 2.14e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.64e+03    |
# |    ep_rew_mean          | 6.53e+05    |
# | time/                   |             |
# |    fps                  | 367         |
# |    iterations           | 11          |
# |    time_elapsed         | 61          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.011281053 |
# |    clip_fraction        | 0.17        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10         |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.01        |
# |    loss                 | 4.8e+05     |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00658    |
# |    value_loss           | 1.27e+06    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 8.64e+03   |
# |    ep_rew_mean          | 6.53e+05   |
# | time/                   |            |
# |    fps                  | 368        |
# |    iterations           | 12         |
# |    time_elapsed         | 66         |
# |    total_timesteps      | 24576      |
# | train/                  |            |
# |    approx_kl            | 0.01012603 |
# |    clip_fraction        | 0.137      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -9.95      |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.01       |
# |    loss                 | 3.52e+06   |
# |    n_updates            | 110        |
# |    policy_gradient_loss | -0.0145    |
# |    value_loss           | 8e+06      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.64e+03    |
# |    ep_rew_mean          | 7.36e+05    |
# | time/                   |             |
# |    fps                  | 370         |
# |    iterations           | 13          |
# |    time_elapsed         | 71          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.008186551 |
# |    clip_fraction        | 0.0816      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -9.91       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.01        |
# |    loss                 | 1.57e+06    |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00537    |
# |    value_loss           | 4.31e+06    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.64e+03    |
# |    ep_rew_mean          | 7.36e+05    |
# | time/                   |             |
# |    fps                  | 370         |
# |    iterations           | 14          |
# |    time_elapsed         | 77          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.015786143 |
# |    clip_fraction        | 0.205       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -9.82       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.01        |
# |    loss                 | 7.99e+04    |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00267    |
# |    value_loss           | 2.57e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.64e+03    |
# |    ep_rew_mean          | 7.36e+05    |
# | time/                   |             |
# |    fps                  | 372         |
# |    iterations           | 15          |
# |    time_elapsed         | 82          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.010994767 |
# |    clip_fraction        | 0.178       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -9.69       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.01        |
# |    loss                 | 1.48e+05    |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00827    |
# |    value_loss           | 3.49e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.64e+03    |
# |    ep_rew_mean          | 7.36e+05    |
# | time/                   |             |
# |    fps                  | 372         |
# |    iterations           | 16          |
# |    time_elapsed         | 87          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.008612817 |
# |    clip_fraction        | 0.0922      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -9.58       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.01        |
# |    loss                 | 4.94e+06    |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00889    |
# |    value_loss           | 1.01e+07    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.64e+03    |
# |    ep_rew_mean          | 8.33e+05    |
# | time/                   |             |
# |    fps                  | 373         |
# |    iterations           | 17          |
# |    time_elapsed         | 93          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.007873327 |
# |    clip_fraction        | 0.0799      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -9.49       |
# |    explained_variance   | -2.38e-07   |
# |    learning_rate        | 0.01        |
# |    loss                 | 3.97e+06    |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00808    |
# |    value_loss           | 9.11e+06    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.64e+03    |
# |    ep_rew_mean          | 8.33e+05    |
# | time/                   |             |
# |    fps                  | 374         |
# |    iterations           | 18          |
# |    time_elapsed         | 98          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.010850765 |
# |    clip_fraction        | 0.162       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -9.4        |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.01        |
# |    loss                 | 2.08e+05    |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00272    |
# |    value_loss           | 3.78e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.64e+03    |
# |    ep_rew_mean          | 8.33e+05    |
# | time/                   |             |
# |    fps                  | 375         |
# |    iterations           | 19          |
# |    time_elapsed         | 103         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.013234263 |
# |    clip_fraction        | 0.202       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -9.3        |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.01        |
# |    loss                 | 1.15e+05    |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0109     |
# |    value_loss           | 3.46e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.64e+03    |
# |    ep_rew_mean          | 8.33e+05    |
# | time/                   |             |
# |    fps                  | 375         |
# |    iterations           | 20          |
# |    time_elapsed         | 108         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.008363054 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -9.29       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.01        |
# |    loss                 | 5.67e+06    |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00971    |
# |    value_loss           | 9.83e+06    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.64e+03    |
# |    ep_rew_mean          | 8.33e+05    |
# | time/                   |             |
# |    fps                  | 375         |
# |    iterations           | 21          |
# |    time_elapsed         | 114         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.009509826 |
# |    clip_fraction        | 0.0951      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -9.2        |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.01        |
# |    loss                 | 5.46e+06    |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0112     |
# |    value_loss           | 1.22e+07    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8.64e+03     |
# |    ep_rew_mean          | 9.2e+05      |
# | time/                   |              |
# |    fps                  | 376          |
# |    iterations           | 22           |
# |    time_elapsed         | 119          |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0125142615 |
# |    clip_fraction        | 0.171        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -9.09        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.01         |
# |    loss                 | 1.66e+05     |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00323     |
# |    value_loss           | 7.45e+05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.64e+03    |
# |    ep_rew_mean          | 9.2e+05     |
# | time/                   |             |
# |    fps                  | 375         |
# |    iterations           | 23          |
# |    time_elapsed         | 125         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.012687494 |
# |    clip_fraction        | 0.214       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -9.03       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.01        |
# |    loss                 | 1.08e+05    |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00421    |
# |    value_loss           | 3.4e+05     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8.64e+03     |
# |    ep_rew_mean          | 9.2e+05      |
# | time/                   |              |
# |    fps                  | 372          |
# |    iterations           | 24           |
# |    time_elapsed         | 132          |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0075037978 |
# |    clip_fraction        | 0.0785       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -9.01        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.01         |
# |    loss                 | 3.66e+06     |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.00663     |
# |    value_loss           | 7.08e+06     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.64e+03    |
# |    ep_rew_mean          | 9.2e+05     |
# | time/                   |             |
# |    fps                  | 372         |
# |    iterations           | 25          |
# |    time_elapsed         | 137         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.008001344 |
# |    clip_fraction        | 0.0551      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.96       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.01        |
# |    loss                 | 6.21e+06    |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00794    |
# |    value_loss           | 1.41e+07    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.64e+03    |
# |    ep_rew_mean          | 9.94e+05    |
# | time/                   |             |
# |    fps                  | 371         |
# |    iterations           | 26          |
# |    time_elapsed         | 143         |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.009473216 |
# |    clip_fraction        | 0.125       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.92       |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.01        |
# |    loss                 | 1.3e+06     |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00881    |
# |    value_loss           | 3.96e+06    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.64e+03    |
# |    ep_rew_mean          | 9.94e+05    |
# | time/                   |             |
# |    fps                  | 371         |
# |    iterations           | 27          |
# |    time_elapsed         | 148         |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.022671254 |
# |    clip_fraction        | 0.233       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.81       |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.01        |
# |    loss                 | 7.22e+04    |
# |    n_updates            | 260         |
# |    policy_gradient_loss | 0.000705    |
# |    value_loss           | 3.15e+05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8.64e+03     |
# |    ep_rew_mean          | 9.94e+05     |
# | time/                   |              |
# |    fps                  | 371          |
# |    iterations           | 28           |
# |    time_elapsed         | 154          |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0085188765 |
# |    clip_fraction        | 0.112        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -8.85        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.01         |
# |    loss                 | 1.66e+06     |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.00413     |
# |    value_loss           | 4.44e+06     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.64e+03    |
# |    ep_rew_mean          | 9.94e+05    |
# | time/                   |             |
# |    fps                  | 371         |
# |    iterations           | 29          |
# |    time_elapsed         | 159         |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.008406002 |
# |    clip_fraction        | 0.0869      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.79       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.01        |
# |    loss                 | 7.23e+06    |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0117     |
# |    value_loss           | 1.46e+07    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 8.64e+03   |
# |    ep_rew_mean          | 1.06e+06   |
# | time/                   |            |
# |    fps                  | 371        |
# |    iterations           | 30         |
# |    time_elapsed         | 165        |
# |    total_timesteps      | 61440      |
# | train/                  |            |
# |    approx_kl            | 0.00756646 |
# |    clip_fraction        | 0.0643     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -8.75      |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.01       |
# |    loss                 | 4.17e+06   |
# |    n_updates            | 290        |
# |    policy_gradient_loss | -0.00557   |
# |    value_loss           | 7.1e+06    |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 8.64e+03  |
# |    ep_rew_mean          | 1.06e+06  |
# | time/                   |           |
# |    fps                  | 370       |
# |    iterations           | 31        |
# |    time_elapsed         | 171       |
# |    total_timesteps      | 63488     |
# | train/                  |           |
# |    approx_kl            | 0.0731325 |
# |    clip_fraction        | 0.375     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -8.69     |
# |    explained_variance   | 5.96e-08  |
# |    learning_rate        | 0.01      |
# |    loss                 | 2.65e+05  |
# |    n_updates            | 300       |
# |    policy_gradient_loss | 0.00855   |
# |    value_loss           | 3.01e+05  |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.64e+03    |
# |    ep_rew_mean          | 1.06e+06    |
# | time/                   |             |
# |    fps                  | 368         |
# |    iterations           | 32          |
# |    time_elapsed         | 177         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.021132996 |
# |    clip_fraction        | 0.289       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.64       |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.01        |
# |    loss                 | 3.71e+05    |
# |    n_updates            | 310         |
# |    policy_gradient_loss | 0.00599     |
# |    value_loss           | 8.93e+05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8.64e+03     |
# |    ep_rew_mean          | 1.06e+06     |
# | time/                   |              |
# |    fps                  | 367          |
# |    iterations           | 33           |
# |    time_elapsed         | 184          |
# |    total_timesteps      | 67584        |
# | train/                  |              |
# |    approx_kl            | 0.0071479403 |
# |    clip_fraction        | 0.113        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -8.57        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.01         |
# |    loss                 | 7.62e+06     |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.00711     |
# |    value_loss           | 1.56e+07     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.64e+03    |
# |    ep_rew_mean          | 1.11e+06    |
# | time/                   |             |
# |    fps                  | 366         |
# |    iterations           | 34          |
# |    time_elapsed         | 189         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.008926682 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.62       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.01        |
# |    loss                 | 4.91e+06    |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.0081     |
# |    value_loss           | 1.02e+07    |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 8.64e+03  |
# |    ep_rew_mean          | 1.11e+06  |
# | time/                   |           |
# |    fps                  | 366       |
# |    iterations           | 35        |
# |    time_elapsed         | 195       |
# |    total_timesteps      | 71680     |
# | train/                  |           |
# |    approx_kl            | 55.027832 |
# |    clip_fraction        | 0.726     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -5.05     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.01      |
# |    loss                 | 8.75e+04  |
# |    n_updates            | 340       |
# |    policy_gradient_loss | 0.2       |
# |    value_loss           | 3.41e+05  |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.64e+03    |
# |    ep_rew_mean          | 1.11e+06    |
# | time/                   |             |
# |    fps                  | 366         |
# |    iterations           | 36          |
# |    time_elapsed         | 200         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.009952702 |
# |    clip_fraction        | 0.164       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.722      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.01        |
# |    loss                 | 1.06e+05    |
# |    n_updates            | 350         |
# |    policy_gradient_loss | 0.00154     |
# |    value_loss           | 2.93e+05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8.64e+03     |
# |    ep_rew_mean          | 1.11e+06     |
# | time/                   |              |
# |    fps                  | 367          |
# |    iterations           | 37           |
# |    time_elapsed         | 206          |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 0.0014180185 |
# |    clip_fraction        | 0.0136       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.715       |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.01         |
# |    loss                 | 7.01e+06     |
# |    n_updates            | 360          |
# |    policy_gradient_loss | 0.000692     |
# |    value_loss           | 1.69e+07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8.64e+03     |
# |    ep_rew_mean          | 1.18e+06     |
# | time/                   |              |
# |    fps                  | 367          |
# |    iterations           | 38           |
# |    time_elapsed         | 211          |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0005188092 |
# |    clip_fraction        | 0.0231       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.693       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.01         |
# |    loss                 | 8.46e+06     |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.000577    |
# |    value_loss           | 1.73e+07     |
# ------------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 8.64e+03  |
# |    ep_rew_mean          | 1.18e+06  |
# | time/                   |           |
# |    fps                  | 367       |
# |    iterations           | 39        |
# |    time_elapsed         | 217       |
# |    total_timesteps      | 79872     |
# | train/                  |           |
# |    approx_kl            | 10.309236 |
# |    clip_fraction        | 0.563     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.799    |
# |    explained_variance   | 1.79e-07  |
# |    learning_rate        | 0.01      |
# |    loss                 | 1.62e+05  |
# |    n_updates            | 380       |
# |    policy_gradient_loss | 0.123     |
# |    value_loss           | 4.44e+05  |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 8.64e+03  |
# |    ep_rew_mean          | 1.18e+06  |
# | time/                   |           |
# |    fps                  | 367       |
# |    iterations           | 40        |
# |    time_elapsed         | 222       |
# |    total_timesteps      | 81920     |
# | train/                  |           |
# |    approx_kl            | 3.3754706 |
# |    clip_fraction        | 0.476     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.75     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.01      |
# |    loss                 | 3.9e+04   |
# |    n_updates            | 390       |
# |    policy_gradient_loss | 0.0479    |
# |    value_loss           | 1.05e+05  |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 8.64e+03  |
# |    ep_rew_mean          | 1.18e+06  |
# | time/                   |           |
# |    fps                  | 367       |
# |    iterations           | 41        |
# |    time_elapsed         | 228       |
# |    total_timesteps      | 83968     |
# | train/                  |           |
# |    approx_kl            | 1.1179445 |
# |    clip_fraction        | 0.966     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.21     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.01      |
# |    loss                 | 3.85e+06  |
# |    n_updates            | 400       |
# |    policy_gradient_loss | 0.162     |
# |    value_loss           | 7.68e+06  |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.64e+03    |
# |    ep_rew_mean          | 1.18e+06    |
# | time/                   |             |
# |    fps                  | 367         |
# |    iterations           | 42          |
# |    time_elapsed         | 233         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.013609311 |
# |    clip_fraction        | 0.121       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.24       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.01        |
# |    loss                 | 6.19e+06    |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.0101     |
# |    value_loss           | 1.21e+07    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.64e+03    |
# |    ep_rew_mean          | 1.21e+06    |
# | time/                   |             |
# |    fps                  | 367         |
# |    iterations           | 43          |
# |    time_elapsed         | 239         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.039725475 |
# |    clip_fraction        | 0.181       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.22       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.01        |
# |    loss                 | 2.04e+06    |
# |    n_updates            | 420         |
# |    policy_gradient_loss | 0.00634     |
# |    value_loss           | 1.87e+06    |
# -----------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 8.64e+03 |
# |    ep_rew_mean          | 1.21e+06 |
# | time/                   |          |
# |    fps                  | 368      |
# |    iterations           | 44       |
# |    time_elapsed         | 244      |
# |    total_timesteps      | 90112    |
# | train/                  |          |
# |    approx_kl            | 46.77835 |
# |    clip_fraction        | 0.967    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -1.25    |
# |    explained_variance   | 1.79e-07 |
# |    learning_rate        | 0.01     |
# |    loss                 | 1.35e+05 |
# |    n_updates            | 430      |
# |    policy_gradient_loss | 0.302    |
# |    value_loss           | 3.9e+05  |
# --------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.64e+03    |
# |    ep_rew_mean          | 1.21e+06    |
# | time/                   |             |
# |    fps                  | 368         |
# |    iterations           | 45          |
# |    time_elapsed         | 250         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.025180249 |
# |    clip_fraction        | 0.277       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.27       |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.01        |
# |    loss                 | 5.95e+05    |
# |    n_updates            | 440         |
# |    policy_gradient_loss | 0.00678     |
# |    value_loss           | 1.48e+06    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.64e+03    |
# |    ep_rew_mean          | 1.21e+06    |
# | time/                   |             |
# |    fps                  | 368         |
# |    iterations           | 46          |
# |    time_elapsed         | 255         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.015158416 |
# |    clip_fraction        | 0.245       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.26       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.01        |
# |    loss                 | 6.73e+05    |
# |    n_updates            | 450         |
# |    policy_gradient_loss | 0.00382     |
# |    value_loss           | 1.53e+06    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.64e+03    |
# |    ep_rew_mean          | 1.12e+06    |
# | time/                   |             |
# |    fps                  | 368         |
# |    iterations           | 47          |
# |    time_elapsed         | 261         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.015892223 |
# |    clip_fraction        | 0.253       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.2        |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.01        |
# |    loss                 | 6.05e+05    |
# |    n_updates            | 460         |
# |    policy_gradient_loss | 0.00637     |
# |    value_loss           | 1.42e+06    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 8.64e+03   |
# |    ep_rew_mean          | 1.12e+06   |
# | time/                   |            |
# |    fps                  | 368        |
# |    iterations           | 48         |
# |    time_elapsed         | 266        |
# |    total_timesteps      | 98304      |
# | train/                  |            |
# |    approx_kl            | 0.02753556 |
# |    clip_fraction        | 0.361      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.26      |
# |    explained_variance   | -1.19e-07  |
# |    learning_rate        | 0.01       |
# |    loss                 | 5.77e+05   |
# |    n_updates            | 470        |
# |    policy_gradient_loss | 0.0125     |
# |    value_loss           | 1.69e+06   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 8.64e+03   |
# |    ep_rew_mean          | 1.12e+06   |
# | time/                   |            |
# |    fps                  | 368        |
# |    iterations           | 49         |
# |    time_elapsed         | 272        |
# |    total_timesteps      | 100352     |
# | train/                  |            |
# |    approx_kl            | 0.01750328 |
# |    clip_fraction        | 0.28       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.37      |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.01       |
# |    loss                 | 4.53e+05   |
# |    n_updates            | 480        |
# |    policy_gradient_loss | 0.00613    |
# |    value_loss           | 1.11e+06   |
# ----------------------------------------

# %%
#predict using learned polocy 
import numpy as np
obs = env.reset()  # Reset the environment to get the initial observation/state
done = False 
#obs = env.reset()
count=0
#done=False
n=9000
Solar_power=np.zeros(n)
Wind_power=np.zeros(n)
generator_power=np.zeros(n)
Cost=np.zeros(n)
operational_cost=np.zeros(n)
Sell_back_to_grid=np.zeros(n)
E_t=np.zeros(n)
state_Soc=np.zeros(n)
while True:
    #print(count)
    # Take a random action
    action, _ = learned_policy.predict(obs, deterministic=True)  # Predict action based on the current observation
    obs, reward, done, info = env.step(action)
    info_to_list=list(info.values())
    
    Solar_power[count]=info_to_list[0]
    Wind_power[count]=info_to_list[1]
    generator_power[count]=info_to_list[2]
    Cost[count]=info_to_list[3]
    Sell_back_to_grid[count]=info_to_list[4]
    operational_cost[count]=info_to_list[5]
    E_t[count]=info_to_list[6]
    state_Soc[count]=info_to_list[7]
    count+=1
    #print(obs)
    
    if done == True:
        break

#env.close()



##info

# %%
#plot results
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Create a DataFrame with your time series data
# Replace these with your actual data
num_points = 9000
time_index = pd.date_range(start='2023-01-01', periods=num_points, freq='H')


data = {
    "Time": time_index,
    "Solar_power": Solar_power,
    "Wind_power": Wind_power,
    "generator_power": generator_power,
    "Cost": Cost,
    "operational_cost": operational_cost,
    "Sell_back_to_grid":Sell_back_to_grid,
    "E_t":E_t,
    "state_Soc":state_Soc
}
df=pd.DataFrame(data)
df_melted = df.melt(id_vars=["Time"], value_vars=["Solar_power", "Wind_power", "generator_power", "Cost", "operational_cost", "Sell_back_to_grid","E_t","state_Soc"])

# Create a facet grid
g = sns.FacetGrid(df_melted, col="variable", col_wrap=4, height=3, aspect=1.5)
g.map(sns.lineplot, "Time", "value")
g.set_axis_labels("Time", "Value")
g.set_titles(col_template="{col_name}")
plt.show()

# %%
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
#random policy
import numpy as np

#obs = env.reset()
count=0
#done=False
n=20000
Solar_power=np.zeros(n)
Wind_power=np.zeros(n)
generator_power=np.zeros(n)
Cost=np.zeros(n)
operational_cost=np.zeros(n)
Sell_back_to_grid=np.zeros(n)
E_t=np.zeros(n)
state_Soc=np.zeros(n)
while True:
    # Take a random action
    action = env.action_space.sample()  # Predict action based on the current observation
    obs, reward, done, info = env.step(action)
    info_to_list=list(info.values())
    #print(info_to_list)                  
    Wind_power[count]=info_to_list[1]
    generator_power[count]=info_to_list[2]
    Cost[count]=info_to_list[3]
    Sell_back_to_grid[count]=info_to_list[4]
    operational_cost[count]=info_to_list[5]
    E_t[count]=info_to_list[6]
    state_Soc[count]=info_to_list[7]
    count+=1
    
    count+=1
   
    
    if done == True:
        break

# %%
#close envirement
env.close()

# %%
#reward convergence plot,ahve to run code snippet nr 1 again

import matplotlib.pyplot as plt

# Initialize an empty list to store rewards
rewards = []
num_episodes=10
#total

# Inside your training loop
for episode in range(num_episodes):
    done = False 
    obs = env.reset()
    total_reward = 0
    
    # Run the episode
    while not done:
        action, _ = model.predict(obs)  # Get action from the trained model
        obs, reward, done, _ = env.step(action)
        total_reward += reward
        rewards.append(total_reward)
        if done == True:
            break
# Plot rewards
plt.plot(rewards)
plt.xlabel('Episode')
plt.ylabel('Total Reward')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 11
#       9 for episode in range(num_episodes):
#      10     done = False
# ---> 11     obs = env.reset()
#      12     total_reward = 0
#      14     # Run the episode
#
# NameError: name 'env' is not defined
